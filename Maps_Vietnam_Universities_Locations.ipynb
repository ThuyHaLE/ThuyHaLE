# %% [markdown]
# <a href="https://colab.research.google.com/github/ThuyHaLE/ThuyHaLE/blob/main/Maps_Vietnam_Universities_Locations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
#!pip3 install folium==0.5.0
import folium
from folium import plugins
print('Folium installed and imported!')
# Out:
# Folium installed and imported!

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Data science/Mine/Maps-Vietnam_University_Locations /Vietnam university list.xlsx'
data = pd.read_excel(path)
data.head()
# Out:
#                        UNIVERSITY NAME  \
# 0          CAO ĐẲNG AN NINH NHÂN DÂN I
# 1         CAO ĐẲNG CẢNH SÁT NHÂN DÂN I
# 2  CAO ĐẲNG CÔNG NGHỆ VÀ KỸ THUẬT Ô TÔ
# 3      CAO ĐẲNG CÔNG NGHIỆP QUỐC PHÒNG
# 4                    CAO ĐẲNG QUÂN Y 1
#
#                                              ADDRESS     CITY AREA  LATITUDE  \
# 0                          ĐỒNG MỐC, SÓC SƠN, HÀ NỘI   HÀ NỘI  BẮC  21.25782
# 1  207 KHUẤT DUY TIẾN, PHƯỜNG NHÂN CHÍNH, QUẬN TH...   HÀ NỘI  BẮC  20.99548
# 2          PHƯỜNG XUÂN KHANH, THỊ XÃ SƠN TÂY, HÀ NỘI   HÀ NỘI  BẮC  21.09712
# 3           THANH VINH, THỊ XÃ PHÚ THỌ, TỈNH PHÚ THỌ  PHÚ THỌ  BẮC  21.39963
# 4        CHÙA THÔNG, PHƯỜNG SƠN LỘC, SƠN TÂY, HÀ NỘI   HÀ NỘI  BẮC  21.14053
#
#    LONGITUDE
# 0  105.84894
# 1  105.81280
# 2  105.47439
# 3  105.22221
# 4  105.50686

# %%
#Pop-up text to each marker and group the markers into different clusters on the map
# Viet Nam latitude and longitude values
latitude = 14.058324
longitude = 108.277199
#Create map and display it
vietnam_map = folium.Map(location=[latitude, longitude], zoom_start=5) #tiles='Stamen Terrain #zoom_start = zoom level
#tiles:'Stamen Toner' => high-contrast B+W (black and white); 'Stamen Terrain' => hill shading and natural vegetation colors

#Instantiate a mark cluster object for the locations in the dataframe
locations = plugins.MarkerCluster().add_to(vietnam_map)
#Loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(data.LATITUDE, data.LONGITUDE, data['UNIVERSITY NAME']):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(locations)
# display map
vietnam_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a34f29418f8d24478d1c8319a04d15e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a34f29418f8d24478d1c8319a04d15e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8a34f29418f8d24478d1c8319a04d15e = L.map(
#                 &quot;map_8a34f29418f8d24478d1c8319a04d15e&quot;,
#                 {
#                     center: [14.058324, 108.277199],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7418e95f44245c6542b29cdc2af2d833 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8a34f29418f8d24478d1c8319a04d15e);
#
#
#             var marker_cluster_6e69505dec99a418fd422c2363dfddb2 = L.markerClusterGroup(
#                 {}
#             );
#             map_8a34f29418f8d24478d1c8319a04d15e.addLayer(marker_cluster_6e69505dec99a418fd422c2363dfddb2);
#
#
#             var marker_40b5a6e7b77c9f93a364ae93af00c2d7 = L.marker(
#                 [21.25782, 105.84894],
#                 {}
#             ).addTo(marker_cluster_6e69505dec99a418fd422c2363dfddb2);
#
#
#         var popup_3f3499d6a8076132fe0a7b7a404ae1b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_19fadf8efce8e72e7c8b4583e0b3c883 = $(`&lt;div id=&quot;html_19fadf8efce8e72e7c8b4583e0b3c883&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CAO ĐẲNG AN NINH NHÂN DÂN I&lt;/div&gt;`)[0];
#             popup_3f3499d6a8076132fe0a7b7a404ae1b3.setContent(html_19fadf8efce8e72e7c8b4583e0b3c883);
#
#
#         marker_40b5a6e7b77c9f93a364ae93af00c2d7.bindPopup(popup_3f3499d6a8076132fe0a7b7a404ae1b3)
#         ;
#
#
#
#
#             var marker_f393aad1f26b2d9ebbf9050cd9b40f07 = L.marker(
#                 [20.99548, 105.8128],
#                 {}
#             ).addTo(marker_cluster_6e69505dec99a418fd422c2363dfddb2);
#
#
#         var popup_919087afc421d8a4fdbd5fe5cf72605d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9f23fd16740270d88583ea8355ac94fa = $(`&lt;div id=&quot;html_9f23fd16740270d88583ea8355ac94fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CAO ĐẲNG CẢNH SÁT NHÂN DÂN I&lt;/div&gt;`)[0];
#             popup_919087afc421d8a4fdbd5fe5cf72605d.setContent(html_9f23fd16740270d88583ea8355ac94fa);
#
#
#         marker_f393aad1f26b2d9ebbf9050cd9b40f07.bindPopup(popup_919087afc421d8a4fdbd5fe5cf72605d)
#         ;
#
#
#
#
#             var marker_aab8d60bd496431673cf21f2427995e0 = L.marker(
#                 [21.09712, 105.47439],
#                 {}
#             ).addTo(marker_cluster_6e69505dec99a418fd422c2363dfddb2);
#
#
#         var popup_d5d269c0bc7ad4c4d054750d171981e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_993d2b33e93d77ee67b0daae07836ab4 = $(`&lt;div id=&quot;html_993d2b33e93d77ee67b0daae07836ab4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CAO ĐẲNG CÔNG NGHỆ VÀ KỸ THUẬT Ô TÔ&lt;/div&gt;`)[0];
#             popup_d5d269c0bc7ad4c4d054750d171981e6.setContent(html_993d2b33e93d77ee67b0daae07836ab4);
#
#
#         marker_aab8d60bd496431673cf21f2427995e0.bindPopup(popup_d5d269c0bc7ad4c4d054750d171981e6)
#         ;
#
#
#
#
#             var marker_277eebd4dbeb6255a2caa807ee2a7ab0 = L.marker(
#                 [21.39963, 105.22221],
#                 {}
#             ).addTo(marker_cluster_6e69505dec99a418fd422c2363dfddb2);
#
#
#         var popup_23fda73093d33768047a6560bbb9e26b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3f9f829b2040af9796e78a77d1816791 = $(`&lt;div id=&quot;html_3f9f829b2040af9796e78a77d1816791&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CAO ĐẲNG CÔNG NGHIỆP QUỐC PHÒNG&lt;/div&gt;`)[0];
#             popup_23fda73093d33768047a6560bbb9e26b.setContent(html_3f9f829b2040af9796e78a77d1816791);
#
#
#         marker_277eebd4dbeb6255a2caa807ee2a7ab0.bindPopup(popup_23fda73093d33768047a6560bbb9e26b)
#         ;
#
#
#
#
#             var marker_c24e4e0ada211b353c9fd37b605633ec = L.marker(
#                 [21.14053, 105.50686],
#                 {}
#             ).addTo(marker_cluster_6e69505dec99a418fd422c2363dfddb2);
#
#
#         var popup_3e43ff4a7bc5e795de35024688d9d665 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_10b096a022d3900b10dd4d42422d2f7f = $(`&lt;div id=
